# %% [markdown]
# # Analysing ESG report using Natural Language Processing
# by Chee-Foong on 12 Mar 2021, updated by Jingjie Yeo on 29 Jun 2022
#
#
# ## Summary
# Environment, Social and Corporate Governance (ESG) refers to the three central factors in measuring the sustainability and societal impact of an investment in a company or business.  These criteria help to better determine the future financial performance of companies (return and risk).
#
# This analysis extracts text from a ESG report in PDF format from the internet, performs NLP on these information, summaries the key ESG initiatives with WordClouds, Tf-IDFs and discovers topics by building a Latent Dirichlet Allocation (LDA) model.
#
# As ESG is a broad topic, different companies focus on different aspects of ESG depending on their business operations and culture. We will ingest  ESG reports from different companies across several sectors and industries to capture relevant ESG topics.
#
#
# ## Reference
#
# 1. [A data-driven approach to Environmental, Social and Governance](https://databricks.com/blog/2020/07/10/a-data-driven-approach-to-environmental-social-and-governance.html)
# 2. [Higher ESG ratings are generally positively correlated with valuation and profitability while negatively correlated with volatility.](https://corpgov.law.harvard.edu/2020/01/14/esg-matters/)
# 3. [Topic Modeling with Gensim (Python)](https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/)
# 4. [Citibank's 2019 ESG report](https://www.citigroup.com/citi/about/esg/download/2019/Global-ESG-Report-2019.pdf?ieNocache=967)
# 5. [Databricks - ESG Reports](https://databricks.com/notebooks/esg_notebooks/01_esg_report.html)
# 5. [Databricks - Data Driven ESG Score](https://databricks.com/notebooks/esg_notebooks/02_esg_scoring.html)
# 6. [Databricks - ESG Market Risk](https://databricks.com/notebooks/esg_notebooks/03_esg_market.html)
# 7. [Topic Modeling and Latent Dirichlet Allocation (LDA) in Python](https://towardsdatascience.com/topic-modeling-and-latent-dirichlet-allocation-in-python-9bf156893c24)
# 8. [Evaluate Topic Models: Latent Dirichlet Allocation (LDA)](https://towardsdatascience.com/evaluate-topic-model-in-python-latent-dirichlet-allocation-lda-7d57484bb5d0)
# 9. [Topic modeling visualization – How to present the results of LDA models?](https://www.machinelearningplus.com/nlp/topic-modeling-visualization-how-to-present-results-lda-models/)

# %% [markdown]
# ---
# ## Import Libraries

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=Warning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
# %matplotlib inline

import pandas as pd
import numpy as np

# pd.options.display.max_columns = 50
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', 50)

plt.rcParams.update({'figure.figsize':(15,6), 'figure.dpi':60})
plt.style.use('fivethirtyeight')

# %%
import sys  
sys.path.append('../src') 
from edge import *

# %%
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim_models  # don't skip this

# PDF text extraction
from pdfminer.layout import LAParams, LTTextBox
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.converter import PDFPageAggregator
from pdfminer.converter import TextConverter

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

# Others
import requests
import io
import string
import re
from pprint import pprint
from tqdm.notebook import tqdm
import io
import urllib3

# %%
# Create Folder to store .json data
DATA_FOLDER = '../data/'
createfolder(DATA_FOLDER)
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Loading Language Model

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')

import spacy
spacy.cli.download("en_core_web_sm")
nlp = spacy.load("en_core_web_sm", disable=['ner'])
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [nltk_data] Downloading package punkt to /Users/Angela/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/Angela/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# ### Preparing Stop Words

# %%
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

from sklearn.feature_extraction import text
stop_words = text.ENGLISH_STOP_WORDS.union(stop_words)
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
', '.join(stop_words)
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# "former, indeed, wherein, be, between, otherwise, un, whereby, amongst, sometimes, hasn't, besides, anyhow, go, full, so, a, that, their, do, into, until, you're, most, nothing, twelve, you'd, shouldn, same, over, may, get, whenever, mightn't, and, anything, doesn't, find, she, co, ever, some, since, cant, y, put, ourselves, name, neither, our, ma, still, next, haven, together, was, anyway, hence, back, when, towards, whereas, first, himself, moreover, all, been, herself, show, serious, five, ll, couldn, both, or, didn't, cry, anyone, meanwhile, by, fill, sometime, won't, well, hadn't, needn't, at, within, wasn't, has, latter, hereafter, aren, ie, rather, whereafter, you've, hadn, if, therefore, s, seeming, it, the, haven't, wouldn't, will, although, they, thick, don, these, ours, what, nowhere, out, which, does, call, empty, being, are, became, didn, twenty, noone, below, around, theirs, against, beside, we, shan, six, except, shouldn't, each, upon, in, yourselves, across, myself, would, last, needn, not, could, her, few, every, itself, very, hasnt, of, should, somehow, beforehand, am, almost, did, whence, my, three, thereafter, with, on, that'll, how, one, whoever, throughout, cannot, per, move, whole, d, front, bill, having, therein, i, them, might, formerly, an, because, made, but, weren, whose, must, nine, thereupon, re, hasn, never, system, via, keep, fifty, those, two, sincere, seemed, ve, only, enough, through, becomes, above, less, side, mustn, etc, something, toward, become, me, another, somewhere, off, someone, there, thereby, alone, due, forty, who, us, elsewhere, mightn, after, behind, down, interest, top, without, whatever, can, though, third, were, part, up, your, whither, than, wouldn, always, isn, again, any, for, don't, detail, least, nobody, wasn, fire, bottom, eleven, everyone, amount, weren't, already, you, please, t, should've, before, namely, about, several, is, describe, hers, give, none, often, perhaps, either, others, m, whether, anywhere, hereupon, thin, mostly, con, here, while, then, de, sixty, aren't, onto, too, hundred, fifteen, during, further, thus, have, it's, thru, o, this, much, done, nevertheless, found, yourself, mustn't, inc, now, such, yet, afterwards, else, isn't, mill, as, seems, thence, ten, own, among, however, yours, herein, whom, doing, everywhere, from, he, had, him, everything, nor, becoming, you'll, ltd, won, couldnt, no, even, doesn, see, once, beyond, its, along, latterly, many, themselves, where, seem, couldn't, just, to, amoungst, eg, also, ain, mine, wherever, take, whereupon, why, four, eight, she's, hereby, under, other, his, more, shan't"

# %% [markdown]
# ## Report Details
#
# Enter required information about the report.  Report must be in PDF format and downloadable from a URL.
#
# 1. Company Name
# 2. Company Ticker Symbol
# 3. Year of the Report
# 4. URL of the Report

# %%
# Cabot Corp
report_company = 'cabot'
report_ticker = 'CBT'
report_year = '2021'
report_url = 'https://www.cabotcorp.com/-/media/files/reports/responsibility/cabot-corporation-sustainability-report-2021.pdf?la=en&rev=5b2b1b0ee3154b5a9a8f32e772b10a2d'

# MIT
#report_company = 'mit'
#report_ticker = 'nothing'
#report_year = '2021'
#report_url = 'https://sustainability.mit.edu/sites/default/files/2022-01/presidents_report_2021_web.pdf'

# General Motors
#report_company = 'gm'
#report_ticker = 'GM'
#report_year = '2021'
#report_url = 'https://www.gmsustainability.com/_pdf/resources-and-downloads/GM_2021_SR.pdf'

# Microsoft
#report_company = 'microsoft'
#report_ticker = 'MSFT'
#report_year = '2021'
#report_url = 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4RwfV'
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Text Extraction
# Extract information from the PDF report.  This process may take some time.  Do be patient.
#
# *You may skip to the last step of this section if you have previously extracted the contents and stored in a json file.*

# %%
def extract_pdf(file, verbose=False):
    
    if verbose:
        print('Processing {}'.format(file))

    try:
        resource_manager = PDFResourceManager()
        fake_file_handle = io.StringIO()
        laparams = LAParams()

        converter = TextConverter(resource_manager, fake_file_handle, laparams=laparams)
        page_interpreter = PDFPageInterpreter(resource_manager, converter)
        
        password = ""
        maxpages = 0
        pagenos = set()

        content = []

        for page in PDFPage.get_pages(file,
                                      pagenos, 
                                      maxpages=maxpages,
                                      password=password,
                                      caching=True,
                                      check_extractable=False):

            page_interpreter.process_page(page)

            content.append(fake_file_handle.getvalue())

            fake_file_handle.truncate(0)
            fake_file_handle.seek(0)        

        text = '##PAGE_BREAK##'.join(content)

        # close open handles
        converter.close()
        fake_file_handle.close()
        
        return text

    except Exception as e:
        print(e)

        # close open handles
        converter.close()
        fake_file_handle.close()

        return ""
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def extract_content(url):
    """
    A simple user define function that, given a url, download PDF text content
    Parse PDF and return plain text version
    """
    headers={"User-Agent":"Mozilla/5.0"}

    try:
        # retrieve PDF binary stream
        r = requests.get(url, allow_redirects=True, headers=headers)
        
        # access pdf content
        text = extract_pdf(io.BytesIO(r.content))

        # return concatenated content
        return text

    except:
        return ""
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
report_content = extract_content(report_url)
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#Storing all information in a json file
import json
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
report = {'company':report_company, 'year':report_year, 'ticker':report_ticker, 
          'url':report_url, 'content':report_content}

with open(DATA_FOLDER + report_company + report_year + '.json', "w") as outfile:  
    json.dump(report, outfile)
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Reloading the json file when required
with open(DATA_FOLDER + report_company + report_year + '.json') as inputfile:
     report = json.load(inputfile)
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Natural Language Processing
#
# ### Extracting content by pages and sentences
#
# 1. Only properly structured sentences are extracted.  Sentences that start with a Capital Letter and ends with a period.  Sentences that are less than 10 words or more than 50 words are ignored.
# 2. Pages with less than 500 words are excluded from extraction.  Would like to focus on pages with mostly text content.  This should exclude pages like cover and last page.  It should also exclude pages that are more graphical with short notes and comments.

# %%
def remove_non_ascii(text):
    printable = set(string.printable)
    return ''.join(filter(lambda x: x in printable, text))

def not_header(line):
    # as we're consolidating broken lines into paragraphs, we want to make sure not to include headers
    return not line.isupper()

def extract_sentences(nlp, text):
    """
    Extracting ESG statements from raw text by removing junk, URLs, etc.
    We group consecutive lines into paragraphs and use spacy to parse sentences.
    """
    MIN_WORDS_PER_PAGE = 500
    
    pages = text.split('##PAGE_BREAK##')
#     print('Number of Pages: {}'.format(len(pages)))

    lines = []
    for page in pages:
        
        # remove non ASCII characters
        text = remove_non_ascii(page)
        
        if len(text.split(' ')) < MIN_WORDS_PER_PAGE:
#             print('Skipped Page: {}'.format(len(text.split(' '))))
            continue
        
        prev = ""
        for line in text.split('\n\n'):
            # aggregate consecutive lines where text may be broken down
            # only if next line starts with a space or previous does not end with dot.
            if(line.startswith(' ') or not prev.endswith('.')):
                prev = prev + ' ' + line
            else:
                # new paragraph
                lines.append(prev)
                prev = line

        # don't forget left-over paragraph
        lines.append(prev)
        lines.append('##SAME_PAGE##')
        
    lines = '  '.join(lines).split('##SAME_PAGE##')
    
    # clean paragraphs from extra space, unwanted characters, urls, etc.
    # best effort clean up, consider a more versatile cleaner
    
    sentences = []
    pages_content = []

    for line in lines[:-1]:
        # removing header number
        line = re.sub(r'^\s?\d+(.*)$', r'\1', line)
        # removing trailing spaces
        line = line.strip()
        # words may be split between lines, ensure we link them back together
        line = re.sub(r'\s?-\s?', '-', line)
        # remove space prior to punctuation
        line = re.sub(r'\s?([,:;\.])', r'\1', line)
        # ESG contains a lot of figures that are not relevant to grammatical structure
        line = re.sub(r'\d{5,}', r' ', line)
        # remove emails
        line = re.sub(r'\S*@\S*\s?', '', line)
        # remove mentions of URLs
        line = re.sub(r'((http|https)\:\/\/)?[a-zA-Z0-9\.\/\?\:@\-_=#]+\.([a-zA-Z]){2,6}([a-zA-Z0-9\.\&\/\?\:@\-_=#])*', r' ', line)
        # remove multiple spaces
        line = re.sub(r'\s+', ' ', line)
        # join next line with space
        line = re.sub(r' \n', ' ', line)
        line = re.sub(r'.\n', '. ', line)
        line = re.sub(r'\x0c', ' ', line)
        
        pages_content.append(str(line).strip())

        # split paragraphs into well defined sentences using spacy
        for part in list(nlp(line).sents):
            sentences.append(str(part).strip())

#           sentences += nltk.sent_tokenize(line)
            
    # Only interested in full sentences and sentences with 10 to 100 words.
    sentences = [s for s in sentences if re.match('^[A-Z][^?!.]*[?.!]$', s) is not None]
    sentences = [s.replace('\n', ' ') for s in sentences]
    sentences = [s for s in sentences if (len(s.split(' ')) > 10) & (len(s.split(' ')) < 100)]

    return pages_content, sentences
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
report_pages, report_sentences = extract_sentences(nlp, report['content'])
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# On best effort basis, excluding header and footer contents that are not relevant.
# May or may not be needed depending on format of reports.
# Ignore for now
"""
headers = ['CABOT CORPORATION 2016 SUSTAINABILITY REPORT', 'CABOT CORPORATION 2020 SUSTAINABILITY REPORT']

for header in headers:
    report_pages = [p.replace(header, "").strip() for p in report_pages]
    report_sentences = [p.replace(header, "").strip() for p in report_sentences]   
"""
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# '\nheaders = [\'CABOT CORPORATION 2016 SUSTAINABILITY REPORT\', \'CABOT CORPORATION 2020 SUSTAINABILITY REPORT\']\n\nfor header in headers:\n    report_pages = [p.replace(header, "").strip() for p in report_pages]\n    report_sentences = [p.replace(header, "").strip() for p in report_sentences]   \n'

# %% [markdown]
# ### Tokenization, Bigrams and Lemmatization

# %%
def run_NLP(content):

    def sent_to_words(sentences):
        for sentence in sentences:
            yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

    # Define functions for stopwords, bigrams, trigrams and lemmatization
    def remove_stopwords(texts):
        return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

    def make_bigrams(texts):
        return [bigram_mod[doc] for doc in texts]

    def make_trigrams(texts):
        return [trigram_mod[bigram_mod[doc]] for doc in texts]

    def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
        """https://spacy.io/api/annotation"""
        texts_out = []
        for sent in texts:
            doc = nlp(" ".join(sent)) 
            texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
        return texts_out

    data_words = list(sent_to_words(content))

    # Build the bigram and trigram models
    bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
    trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

    # Faster way to get a sentence clubbed as a trigram/bigram
    bigram_mod = gensim.models.phrases.Phraser(bigram)
    trigram_mod = gensim.models.phrases.Phraser(trigram)

    # Remove Stop Words
    data_words_nostops = remove_stopwords(data_words)

    # Form Bigrams
    data_words_bigrams = make_bigrams(data_words_nostops)

    # Do lemmatization keeping only noun, adj, vb, adv
    data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])
    
    return data_lemmatized
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# #### Using full text content in a page rather than full text content in a sentence here.  A page defined as a document as per TFIDF calculation.

# %%
data_lemmatized = run_NLP(report_pages)
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
report_sentences_lemma = [' '.join(w) for w in data_lemmatized]
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import random
report_sentences_lemma[random.randint(0, len(report_sentences_lemma))]
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 'campus test bed mito formative partner leverage campus test bed advance understanding achieve build manage sustainable campus recently enable mito manage methodology bring faculty researcher student operational expert inform current future practice example work range course development student project research datum collection merely find space campus researcher test new innovation campus course solve carbon neutrality mit focus designing solution scenario mit short long term solve carbon neutrality mit lead tor engage student project base learn leverage campus test bed idea spring cohort student craft plan reach net course explore sustainability different scale lead newman explore sustainability different scale provide introduction concept sus tainable development perspective different discipline include business economic science engineer social humanity course use framework sustainable development goal emphasize breadth concept mit campus research education mission focus broad perspective specific example close home class emphasize critical analysis think reading discussion community action meet various expert identify team project final report campus sustainability incubator fund mit seek resume campus operation fall select researcher faculty student staff need vast amount personal protective equipment ppe individual opportunity mito support development strategy framework inform sustainable campus procurement grant sustainability incubator fund campus research er invite craft research proposal study supply chain lifecycle use disposal process potential impact mit campus select research team include representation mit sloan concrete sustainability hub center transportation logistic mit humanitarian supply chain program integrate master student capstone project ppe study student directly leverage campus case study ppe supply chain context sustainability opportunity study conclude finding include market sustainable ppe product develop scale offer reliable performance sustainability benefit mit good opportunity drive sustainability campus procurement focus right size order research team develop ppe demand calculator use entity seek right size order newly launch mit store centralize procurement distribution ppe material store prove highly effi mechanism ensure mit community need optimize sustainability benefit later month store operation mechanism nearly eliminate order establish reliable method ppe access campus lab measure impact sustainability datapool launch mitoss sustainability datapool serve collaborative project provide mit com munity equitable access campus sustainability datum visualization use real time datum tool empower mit community member give datum need stand current performance inform innovative sustainability solution idea multiple new datum set visualiza tion go live datapool include previously mention institute story access mit climate resiliency dashboard expand focus waste level material matter campus waste visualization dashboard important tool research decision make open energy datum tracking toolcontinue support operational deci sion make research essential achieve goal new climate action plan star mit earn star gold rating recognition sustain ability high education star sustainabil ity track assessment rating measure encourage sustainability aspect high education gold rating place mit retain rating achieve high mitosle data scientist roleworke collect institute engage dozen staff faculty student effort result update datum collection submit await acceptance rating'

# %% [markdown]
# #### Relevant sentences are now well defined for ESG corpus.

# %% [markdown]
# ### Word Cloud - Corpus Wide Term Frequencies

# %%
# Context specific keywords not to include in topic modelling
# Need to tune accordingly but we will leave it as it is for now

fsi_stop_words = [
  'plc', 'group', 'target',
  'track', 'capital', 'holding',
  'report', 'annualreport',
  'esg', 'bank', 'report',
  'annualreport', 'long', 'make'
]

fsi_stop_words.append(report_company)

# our list contains all english stop words + companies names + specific keywords
stop_words = stop_words.union(fsi_stop_words)
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from wordcloud import WordCloud

# aggregate all 7200 records into one large string to run wordcloud on term frequency
large_string = ' '.join(report_sentences_lemma)

# use 3rd party lib to compute term freq., apply stop words
word_cloud = WordCloud(
    background_color="white",
    max_words=5000, 
    width=1500, 
    height=1000, 
    stopwords=stop_words, 
    contour_width=3, 
    contour_color='steelblue'
)

# display our wordcloud across all records
plt.figure(figsize=(16,16))
word_cloud.generate(large_string)
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### TFIDF - Unigram and Bigram Analysis

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# Run bi-gram TF-IDF frequencies
bigram_tf_idf_vectorizer = TfidfVectorizer(stop_words=stop_words, ngram_range=(1,2), min_df=1, use_idf=True)
bigram_tf_idf = bigram_tf_idf_vectorizer.fit_transform(report_sentences_lemma)

# Extract bi-grams names
words = bigram_tf_idf_vectorizer.get_feature_names()

# extract our top 10 ngrams
total_counts = np.zeros(len(words))
for t in bigram_tf_idf:
    total_counts += t.toarray()[0]

count_dict = (zip(words, total_counts))
count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:30]
words = [w[0] for w in count_dict]
counts = [w[1] for w in count_dict]
x_pos = np.arange(len(words)) 

# Plot top 10 ngrams
plt.figure(figsize=(16, 6))
plt.subplot(title='30 most common uni-gram and bi-grams')
sns.barplot(x_pos, counts, palette='Blues_r')
plt.xticks(x_pos, words, rotation=90) 
plt.xlabel('N-grams')
plt.ylabel('tfidf')
plt.show()
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ---

# %% [markdown]
# ## Topic Modeling and Latent Dirichlet Allocation (LDA)
#
# Evaluaton Metrics
# 1. **Perplexity**: Captures how surprised a model is of new data it has not seen before, and is measured as the normalized log-likelihood of a held-out test set.  Lower the better.
# 2. **Coherence Score**: Measures score a single topic by measuring the degree of semantic similarity between high scoring words in the topic.  Higher the better.
#
# In the analysis, the model with the highest coherence score is selected as the optimal model.

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
results = []
optimal_score = 0
optimal_model = None

for num_of_topics in tqdm(range(2,15,1)):
    
    result = {}
    
    # Build LDA model
    lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                                id2word=id2word,
                                                num_topics=num_of_topics, 
                                                random_state=42,
                                                update_every=1,
                                                chunksize=5,
                                                passes=20,
                                                alpha='auto',
                                                per_word_topics=True) 

    coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
    
    if optimal_score < coherence_model_lda.get_coherence():
        optimal_score = coherence_model_lda.get_coherence()
        optimal_model = lda_model

    result['num_of_topics'] = num_of_topics
    result['perplexity'] = lda_model.log_perplexity(corpus)
    result['coherence_score'] = coherence_model_lda.get_coherence()
    
    results.append(result)
    
results = pd.DataFrame(results)  
results.set_index('num_of_topics', inplace=True)
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   0%|          | 0/13 [00:00<?, ?it/s]

# %%
results.plot(secondary_y='perplexity')
plt.show()
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
results
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                perplexity  coherence_score
# num_of_topics
# 2               -6.587599         0.193881
# 3               -6.586313         0.256080
# 4               -6.698742         0.307538
# 5               -6.737436         0.305098
# 6               -6.735132         0.316206
# 7               -6.705173         0.295069
# 8               -6.825170         0.288306
# 9               -6.844690         0.257384
# 10              -6.773795         0.276584
# 11              -6.861764         0.274160
# 12              -6.773864         0.279264
# 13              -6.944113         0.297239
# 14              -6.873370         0.277914

# %%
# Compute Perplexity
print('\nPerplexity of the Optimal Model: ', optimal_model.log_perplexity(corpus))  

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=optimal_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score of the Optimal Model: ', coherence_lda)
# Out:
# Perplexity of the Optimal Model:  -6.735132623309671
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Coherence Score of the Optimal Model:  0.31620631016190054

# %% [markdown]
# ---

# %% [markdown]
# ## Visualize the topics

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim_models.prepare(optimal_model, corpus, id2word)
vis
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0     -0.207820  0.007113       1        1  37.038422
# 5      0.016445  0.051705       2        1  21.727356
# 1      0.087389  0.080073       3        1  17.872916
# 3      0.009805 -0.047462       4        1  13.825085
# 4      0.069028 -0.082154       5        1   9.534115
# 2      0.025153 -0.009275       6        1   0.002106, topic_info=              Term       Freq      Total Category  logprob  loglift
# 459      committee  18.000000  18.000000  Default  30.0000  30.0000
# 62        emission  10.000000  10.000000  Default  29.0000  29.0000
# 712  communication  12.000000  12.000000  Default  28.0000  28.0000
# 49           datum  11.000000  11.000000  Default  27.0000  27.0000
# 227           food   6.000000   6.000000  Default  26.0000  26.0000
# ..             ...        ...        ...      ...      ...      ...
# 717   consistently   0.000056   4.153017   Topic6  -6.6871  -0.4489
# 718   conversation   0.000056   4.153017   Topic6  -6.6871  -0.4489
# 733     facilitate   0.000056   4.153017   Topic6  -6.6871  -0.4489
# 751    involvement   0.000056   4.153017   Topic6  -6.6871  -0.4489
# 769       planning   0.000056   4.153017   Topic6  -6.6871  -0.4489
#
# [345 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 579       2  0.734839      access
# 323       4  0.754800  accessible
# 1         3  0.503632     account
# 3         2  0.510698     achieve
# 3         3  0.255349     achieve
# ...     ...       ...         ...
# 184       5  0.113576        work
# 801       1  0.722366   workspace
# 186       3  0.552075        year
# 186       4  0.138019        year
# 186       5  0.276037        year
#
# [369 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 6, 2, 4, 5, 3])

# %%
# Print the keywords in the optimal model
pprint(optimal_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.027*"climate" + 0.022*"sustainability" + 0.022*"committee" + 0.022*"work" '
#   '+ 0.016*"mit" + 0.015*"communication" + 0.014*"mito" + 0.013*"sustainable" '
#   '+ 0.012*"campus" + 0.012*"new"'),
#  (1,
#   '0.026*"emission" + 0.022*"mit" + 0.016*"datum" + 0.015*"change" + '
#   '0.014*"campus" + 0.013*"scope" + 0.011*"year" + 0.009*"mito" + '
#   '0.008*"travel" + 0.008*"mitigation"'),
#  (2,
#   '0.001*"sustainability" + 0.001*"mit" + 0.001*"climate" + 0.001*"campus" + '
#   '0.001*"communication" + 0.001*"work" + 0.001*"sustainable" + 0.001*"waste" '
#   '+ 0.001*"new" + 0.001*"mito"'),
#  (3,
#   '0.019*"mit" + 0.019*"food" + 0.015*"climate" + 0.012*"work" + '
#   '0.012*"campus" + 0.010*"sustainability" + 0.010*"mito" + 0.010*"student" + '
#   '0.008*"team" + 0.008*"risk"'),
#  (4,
#   '0.014*"resiliency" + 0.014*"dashboard" + 0.014*"climate" + 0.013*"work" + '
#   '0.011*"mit" + 0.010*"community" + 0.010*"year" + 0.009*"flooding" + '
#   '0.009*"justice" + 0.009*"potential"'),
#  (5,
#   '0.024*"campus" + 0.023*"mit" + 0.020*"sustainability" + 0.012*"student" + '
#   '0.012*"research" + 0.010*"ppe" + 0.010*"datum" + 0.007*"rating" + '
#   '0.007*"project" + 0.006*"sustainable"')]
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ---

# %% [markdown]
# ## Distinguishing the different ESG topics

# %%
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(stopwords=stop_words,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=50,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = optimal_model.show_topics(formatted=False)

# Currently requires manually changing the rows and columns to suit 
fig, axes = plt.subplots(4, 3, figsize=(15,15), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().axis('off')

plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()
# Out:
# /Users/Angela/opt/anaconda3/envs/pyblio/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-1433f6e29a83> in <module>
#      17 for i, ax in enumerate(axes.flatten()):
#      18     fig.add_subplot(ax)
# ---> 19     topic_words = dict(topics[i][1])
#      20     cloud.generate_from_frequencies(topic_words, max_font_size=300)
#      21     plt.gca().imshow(cloud)
#
# IndexError: list index out of range

# %% [markdown]
# # Closing Notes
# 1. This is only a simple analysis that studies the ESG topics in only one ESG report.  This study can be extended to more reports issued by the many companies across different sectors and industries.
# 2. We can expect the number of topics to increase when more ESG reports are included in the study.
# 3. Once relevant ESG topics are identified, then we can potentially calculate ESG scores by topics for all companies.  Then we can assess and see whether such ESG score derived through NLP process correlates with the score given by rating agencies downloaded from Yahoo Finance.
